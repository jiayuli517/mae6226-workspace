# %%
import numpy
import math
from matplotlib import pyplot
# %matplotlib inline

# %%
3+2j
# Out:
# (3+2j)

# %%
a=3
b=3
z=a+b*1j
print('z',z)
print('The type of the variable is', type(z))
# Out:
# z (3+3j)
# The type of the variable is <class 'complex'>

# %%
a=2.75
b=3.69
z1=a+b*1j
c=8.55
d=6.13
z2=c-d*1j
z=z1*z2
print('z=',z)
# Out:
# z= (46.1322+14.692000000000004j)

# %%
z=1.4*(numpy.e**5.32j)
print('z=',z)
# Out:
# z= (0.799270785858235-1.1494199453957457j)

# %%
z1=7.51-9.15*1j
z2=4.43+9.64*1j
z=z1/z2
print('z=',z)
# Out:
# z= (-0.4880897698448308-1.0033441577191493j)

# %%
def get_function(x,y,z,c):
    z=x+y*1j
    xi=z+c**2/z
    return xi

# %%
R=1.5
a,b=0,0
c=1
theta = numpy.linspace(0, 2*numpy.pi, 100)
x = a + R * numpy.cos(theta)
y = b + R * numpy.sin(theta)

# %%
numpy.shape(x)
# Out:
# (100,)

# %%
xi_1 = get_function (x,y,z,c)

# %%
numpy.shape(xi_1)
# Out:
# (100,)

# %%
size = 10
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.scatter(xi_1.real, xi_1.imag,color='#CD2305', s=10, marker='o')

# %%
R2=1.2
a,b=c-R2,0
theta = numpy.linspace(0, 2*numpy.pi, 100)
x = a + R2 * numpy.cos(theta)
y = b + R2 * numpy.sin(theta)

# %%
xi_2=get_function(x,y,z,c)

# %%
numpy.shape(xi_2)
# Out:
# (100,)

# %%
size = 10
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.scatter(xi_2.real, xi_2.imag,color='#CD2305', s=10, marker='o')

# %%
a,b=-0.1,0.1
R3=numpy.sqrt((c-a)**2+b**2)
theta=numpy.linspace(0, 2*numpy.pi, 100)
x = a + R3 * numpy.cos(theta)
y = b + R3 * numpy.sin(theta)

# %%
numpy.shape(x)
# Out:
# (100,)

# %%
xi_3 = get_function(x,y,z,c)

# %%
numpy.shape(xi_3)
# Out:
# (100,)

# %%
size = 10
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.scatter(xi_3.real, xi_3.imag,color='#CD2305', s=10, marker='o')

# %%
a,b=-0.15,0
R=1.15
c=1

# %%
theta=numpy.linspace(0, 2*numpy.pi, 145)
r=numpy.linspace(R, 5, 100)

# %%
numpy.shape(r)
# Out:
# (100,)

# %%
numpy.shape(theta)
# Out:
# (145,)

# %%
R1,THETA=numpy.meshgrid(r, theta)

# %%
numpy.shape(R1)
# Out:
# (145, 100)

# %%
numpy.shape(THETA)
# Out:
# (145, 100)

# %%
R1,THETA
# Out:
# (array([[ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         ...,
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ]]),
#  array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.04363323,  0.04363323,  0.04363323, ...,  0.04363323,
#           0.04363323,  0.04363323],
#         [ 0.08726646,  0.08726646,  0.08726646, ...,  0.08726646,
#           0.08726646,  0.08726646],
#         ...,
#         [ 6.19591884,  6.19591884,  6.19591884, ...,  6.19591884,
#           6.19591884,  6.19591884],
#         [ 6.23955208,  6.23955208,  6.23955208, ...,  6.23955208,
#           6.23955208,  6.23955208],
#         [ 6.28318531,  6.28318531,  6.28318531, ...,  6.28318531,
#           6.28318531,  6.28318531]]))

# %%
size=10
pyplot.scatter(R1,THETA,color='#CD2305', s=1, marker='o',linewidth=0)

# %%
x=a+R1*numpy.cos(THETA)
y=b+R1*numpy.sin(THETA)

# %%
numpy.shape(x)
# Out:
# (145, 100)

# %%
size=10
pyplot.xlabel('z-plane',fontsize=16)
pyplot.scatter(x,y,color='#CD2305', s=5, marker='o',linewidth=0)

# %%
numpy.shape(x)
# Out:
# (145, 100)

# %%
numpy.shape(y)
# Out:
# (145, 100)

# %%
xi=get_function(x,y,z,c)

# %%
size=10
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.scatter(xi.real,xi.imag,color='#CD2305', s=5, marker='o',linewidth=0)

# %%
u_inf = 1.0
R=1.15
kappa = R**2*2*numpy.pi*u_inf

# %%
kappa
# Out:
# 8.309512568745001

# %%
def get_velocity_doublet(strength, xd, yd, x, y):
    """
    Returns the velocity field generated by a doublet.
    
    Parameters
    ----------
    strength: float
        Strength of the doublet.
    xd: float
        x-coordinate of the doublet.
    yd: float
        y-coordinate of the doublet.
    X: 2D Numpy array of floats
        x-coordinate of the mesh points.
    Y: 2D Numpy array of floats
        y-coordinate of the mesh points.
    
    Returns
    -------
    u: 2D Numpy array of floats
        x-component of the velocity vector field.
    v: 2D Numpy array of floats
        y-component of the velocity vector field.
    """
    u = - strength/(2*math.pi)*((x-xd)**2-(y-yd)**2)/((x-xd)**2+(y-yd)**2)**2
    v = - strength/(2*math.pi)*2*(x-xd)*(y-yd)/((x-xd)**2+(y-yd)**2)**2
    
    return u, v

def get_stream_function_doublet(strength, xd, yd, x, y):
    """
    Returns the stream-function generated by a doublet.
    
    Parameters
    ----------
    strength: float
        Strength of the doublet.
    xd: float
        x-coordinate of the doublet.
    yd: float
        y-coordinate of the doublet.
    X: 2D Numpy array of floats
        x-coordinate of the mesh points.
    Y: 2D Numpy array of floats
        y-coordinate of the mesh points.
    
    Returns
    -------
    psi: 2D Numpy array of floats
        The stream-function.
    """
    psi = - strength/(2*math.pi)*(y-yd)/((x-xd)**2+(y-yd)**2)
    
    return psi

# %%
u_doublet, v_doublet = get_velocity_doublet(kappa, a, b, x, y)
psi_doublet = get_stream_function_doublet(kappa, a, b, x, y)

# %%
u_freestream = u_inf * numpy.ones((145, 100), dtype=float)
v_freestream = numpy.zeros((145, 100), dtype=float)

psi_freestream = u_inf * y

# %%
numpy.shape(u_freestream)
# Out:
# (145, 100)

# %%
# superposition of the doublet on the freestream flow
u = u_freestream + u_doublet
v = v_freestream + v_doublet
psi = psi_freestream + psi_doublet

size = 10
pyplot.xlabel('z-plane',fontsize=16)
pyplot.xlim(-6.0,6.0)
pyplot.ylim(-6.0,6.0)
pyplot.contour(x, y, psi, levels=numpy.linspace(-6.0, 6.0, 50), colors='#CD2305', linewidths=1, linestyles='solid')

# %%
xi=get_function(x,y,z,c)

# %%
size = 10
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.xlim(-6.0,6.0)
pyplot.ylim(-6.0,6.0)
pyplot.contour(xi.real, xi.imag, psi, levels=numpy.linspace(-6.0, 6.0, 50), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
W=(u-v*1j)/(1-(c/z)**2)

# %%
size=10
pyplot.quiver(x,y,u,v)

# %%
xi=get_function(x,y,z,c)
size=10
pyplot.quiver(xi.real,xi.imag,u,v)

# %%
cp = 1.0 - (u**2+v**2)/u_inf**2

# plot the pressure coefficient field
size = 10
pyplot.xlabel('z-plane', fontsize=16)
contf = pyplot.contourf(x, y, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])
pyplot.contour(x, y, psi, levels=[0.],colors='#CD2305', linewidths=2, linestyles='solid');

# %%
size = 10
pyplot.xlabel('xi-plane', fontsize=16)
contf = pyplot.contourf(xi.real, xi.imag, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])
pyplot.contour(xi.real, xi.imag, psi, levels=[0.], colors='#CD2305', linewidths=2, linestyles='solid');

# %%
AoA=20*math.pi/180
x1=(x-a)*numpy.cos(AoA)+(y-b)*numpy.sin(AoA)
y1=-(x-a)*numpy.sin(AoA)+(y-b)*numpy.cos(AoA)

u_doublet, v_doublet = get_velocity_doublet(kappa, 0, 0, x1, y1)
psi_doublet = get_stream_function_doublet(kappa, 0, 0, x1, y1)

u_freestream = u_inf * numpy.ones((145, 100), dtype=float)
v_freestream = numpy.zeros((145, 100), dtype=float)

psi_freestream = u_inf * y1

# superposition of the doublet on the freestream flow
u = u_freestream + u_doublet
v = v_freestream + v_doublet
psi = psi_freestream + psi_doublet

size = 10
pyplot.xlabel('z-plane',fontsize=16)
pyplot.xlim(-6.0,6.0)
pyplot.ylim(-6.0,6.0)
pyplot.contour(x, y, psi, levels=numpy.linspace(-6.0, 6.0, 50), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
def get_function2(x,y,c):
    z=x+y*1j
    z1=(z-(a+b*1j))*numpy.e**AoA*-1j
    xi=z1+c**2/z1
    return xi

# %%
xi=get_function2(x1,y1,c)

# %%
numpy.shape(xi)
# Out:
# (145, 100)

# %%
size = 10
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.xlim(-6.0,6.0)
pyplot.ylim(-6.0,6.0)
pyplot.contour(xi.real, xi.imag, psi, levels=numpy.linspace(-6.0, 6.0, 50), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
W=(u-v*1j)/(1-(c/z)**2)
size=10
pyplot.quiver(x,y,u,v)

# %%
cp = 1.0 - (u**2+v**2)/u_inf**2

# plot the pressure coefficient field
size = 10
pyplot.xlabel('z-plane', fontsize=16)
contf = pyplot.contourf(x, y, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])
pyplot.contour(x, y, psi, levels=[0.], colors='#CD2305', linewidths=2, linestyles='solid');

# %%
xi=get_function(x,y,z,c)
size=10
pyplot.quiver(xi.real,xi.imag,u,v)

# %%
size = 10
pyplot.xlabel('xi-plane', fontsize=16)
contf = pyplot.contourf(xi.real, xi.imag, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])
pyplot.contour(xi.real, xi.imag, psi, levels=[0.], colors='#CD2305', linewidths=2, linestyles='solid');
