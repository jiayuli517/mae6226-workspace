# %% [markdown]
# # 1. Complex numbers in Python

# %%
import numpy
import math
from matplotlib import pyplot
# %matplotlib inline

# %%
3+2j
# Out:
# (3+2j)

# %%
a=3
b=3
z=a+b*1j
print('z=',z)
print('The type of the variable is', type(z))
# Out:
# z= (3+3j)
# The type of the variable is <class 'complex'>

# %%
a=2.75
b=3.69
z1=a+b*1j
c=8.55
d=6.13
z2=c-d*1j
z=z1*z2
print('z=',z)
# Out:
# z= (46.1322+14.692000000000004j)

# %%
z=1.4*(numpy.e**5.32j)
print('z=',z)
# Out:
# z= (0.799270785858235-1.1494199453957457j)

# %%
z1=7.51-9.15*1j
z2=4.43+9.64*1j
z=z1/z2
print('z=',z)
# Out:
# z= (-0.4880897698448308-1.0033441577191493j)

# %% [markdown]
# # 2. Shapes created by the Joukowski transformation

# %%
#Start by writing a Python function
def get_function(x,y):
    z=x+y*1j
    xi=z+c**2/z
    return xi

# %%
c=1.0
N=100
theta = numpy.linspace(0, 2*numpy.pi, N)

#On the z-plane, place a circle with radius R1=1.5, c=1, centered at the origin
R1=1.5
a1,b1=0,0

# %%
def get_x_y(R,a,b,theta):
    x=a+R*numpy.cos(theta)
    y=b+R*numpy.sin(theta)
    return x,y

# %%
x1,y1=get_x_y(R1,a1,b1,theta)

# %%
numpy.shape(x1)
# Out:
# (100,)

# %%
xi_1 = get_function (x1,y1)

# %%
size = 10
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
x_start,x_end=-3.0,3.0
y_start,y_end=-1.0,1.0
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.scatter(xi_1.real, xi_1.imag,color='#CD2305', s=10, marker='o')

# %%
#place a circle on the z-plane with radius R=1.2,centered at (c−R,0)
R2=1.2
a2,b2=c-R2,0

# %%
x2,y2=get_x_y(R2,a2,b2,theta)

# %%
xi_2=get_function(x2,y2)

# %%
numpy.shape(xi_2)
# Out:
# (100,)

# %%
size = 10
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.scatter(xi_2.real, xi_2.imag,color='#CD2305', s=10, marker='o')

# %%
#circle
a3,b3=-0.1,0.1
R3=numpy.sqrt((c-a3)**2+b3**2)

# %%
x3,y3=get_x_y(R3,a3,b3,theta)

# %%
numpy.shape(x3)
# Out:
# (100,)

# %%
xi_3 = get_function(x3,y3)

# %%
numpy.shape(xi_3)
# Out:
# (100,)

# %%
size = 10
pyplot.xlabel('x', fontsize=16)
pyplot.ylabel('y', fontsize=16)
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.scatter(xi_3.real, xi_3.imag,color='#CD2305', s=10, marker='o')

# %% [markdown]
# The point theta=0 corresponds to the trailing edge of the airfoil.

# %% [markdown]
# # 3. Grid points on the z -plane using polar coordinates

# %%
N_r, N_theta=100, 145
a4,b4=-0.15,0
R4=1.15

# %%
theta=numpy.linspace(0, 2*numpy.pi, N_theta)
r=numpy.linspace(R4, 5, N_r)

# %%
R,THETA=numpy.meshgrid(r, theta)

# %%
numpy.shape(R)
# Out:
# (145, 100)

# %%
R,THETA
# Out:
# (array([[ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         ...,
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ],
#         [ 1.15      ,  1.18888889,  1.22777778, ...,  4.92222222,
#           4.96111111,  5.        ]]),
#  array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#           0.        ,  0.        ],
#         [ 0.04363323,  0.04363323,  0.04363323, ...,  0.04363323,
#           0.04363323,  0.04363323],
#         [ 0.08726646,  0.08726646,  0.08726646, ...,  0.08726646,
#           0.08726646,  0.08726646],
#         ...,
#         [ 6.19591884,  6.19591884,  6.19591884, ...,  6.19591884,
#           6.19591884,  6.19591884],
#         [ 6.23955208,  6.23955208,  6.23955208, ...,  6.23955208,
#           6.23955208,  6.23955208],
#         [ 6.28318531,  6.28318531,  6.28318531, ...,  6.28318531,
#           6.28318531,  6.28318531]]))

# %%
x4,y4=get_x_y(R,a4,b4,THETA)

# %%
size=5
x_start,x_end=-6,6
y_start,y_end=-6,6
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('z-plane',fontsize=16)
pyplot.scatter(x4,y4,color='#CD2305', s=5, marker='o',linewidth=0)

# %%
numpy.shape(x4)
# Out:
# (145, 100)

# %%
xi_4=get_function(x4,y4)

# %%
size=5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
x_start,x_end=-6,6
y_start,y_end=-6,6
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.scatter(xi_4.real,xi_4.imag,color='#CD2305', s=5, marker='o',linewidth=0)

# %% [markdown]
# # 4. Flow over a symmetric Joukowski airfoil with zero angle of attack

# %%
u_inf = 1.0
R4=1.15
kappa = R4**2*2*numpy.pi*u_inf

# %%
kappa
# Out:
# 8.309512568745001

# %%
def get_velocity_doublet(strength, xd, yd, x, y):
    
    u = - strength/(2*math.pi)*((x-xd)**2-(y-yd)**2)/((x-xd)**2+(y-yd)**2)**2
    v = - strength/(2*math.pi)*2*(x-xd)*(y-yd)/((x-xd)**2+(y-yd)**2)**2
    
    return u, v

def get_stream_function_doublet(strength, xd, yd, x, y):
    
    psi = - strength/(2*math.pi)*(y-yd)/((x-xd)**2+(y-yd)**2)
    
    return psi

# %%
u_doublet, v_doublet = get_velocity_doublet(kappa, a4, b4, x4, y4)
psi_doublet = get_stream_function_doublet(kappa, a4, b4, x4, y4)

# %%
u_freestream = u_inf * numpy.ones((N_theta, N_r), dtype=float)
v_freestream = numpy.zeros((N_theta, N_r), dtype=float)

psi_freestream = u_inf * y4

# %%
numpy.shape(u_freestream)
# Out:
# (145, 100)

# %%
# superposition of the doublet on the freestream flow
u = u_freestream + u_doublet
v = v_freestream + v_doublet
psi = psi_freestream + psi_doublet

x5,y5=get_x_y(R4,a4,b4,theta)

size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('z-plane',fontsize=16)
pyplot.contour(x4, y4,psi, levels=numpy.linspace(x_start, x_end, 50), colors='#CD2305', linewidths=1, linestyles='solid')
pyplot.scatter(x5,y5,color='#CD2305',s=1);

# %%
xi_5=get_function(x4,y4)

# %%
size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.contour(xi_5.real, xi_5.imag, psi, levels=numpy.linspace(x_start, x_end, 50), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
z = x4 + y4*1j
W = (u - v*1j)/(1-(c/z)**2)

# %%
size=10
x_start,x_end=-3,3
y_start,y_end=-3,3
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.quiver(x4,y4,u,v,units='xy',pivot='tip',width=0.005,scale=40)

# %%
size=10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.quiver(xi_5.real,xi_5.imag,u,v,units='xy',pivot='tip',width=0.005,scale=40)

# %%
cp = 1.0 - (u**2+v**2)/u_inf**2

# plot the pressure coefficient field
size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('z-plane', fontsize=16)
contf = pyplot.contourf(x4, y4, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])

# %%
u_1 = W.real
v_1 = -W.imag
cp_xi = 1.0 - (u_1**2+v_1**2)/u_inf**2

size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('xi-plane', fontsize=16)
contf = pyplot.contourf(xi_5.real, xi_5.imag, cp_xi, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])

# %%
kappa
# Out:
# 8.309512568745001

# %%
W[61][0]
# Out:
# (1.1063384662852436-0.52363334929849692j)

# %%
numpy.min(cp_xi)
# Out:
# -0.68775567409240423

# %% [markdown]
# # 5. Flow over a symmetric Joukowski airfoil with non-zero angle of attack, without circulation

# %%
AoA=20*math.pi/180
x1=(x4-a4)*numpy.cos(AoA)+(y4-b4)*numpy.sin(AoA)
y1=-(x4-a4)*numpy.sin(AoA)+(y4-b4)*numpy.cos(AoA)

u_doublet, v_doublet = get_velocity_doublet(kappa, 0, 0, x1, y1)
psi_doublet = get_stream_function_doublet(kappa, 0, 0, x1, y1)

u_freestream = u_inf * numpy.ones((145, 100), dtype=float)
v_freestream = numpy.zeros((145, 100), dtype=float)

psi_freestream = u_inf * y1

# superposition of the doublet on the freestream flow
u = u_freestream + u_doublet
v = v_freestream + v_doublet
psi = psi_freestream + psi_doublet

u = u*numpy.cos(20*math.pi/180) - v*numpy.sin(20*math.pi/180)
v = u*numpy.sin(20*math.pi/180) + v*numpy.cos(20*math.pi/180)

size = 5
x_start,x_end=-6,6
y_start,y_end=-6,6
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('z-plane',fontsize=16)
pyplot.contour(x4, y4, psi, levels=numpy.linspace(-6.0, 6.0, 50), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.contour(xi_5.real, xi_5.imag, psi, levels=numpy.linspace(-6.0, 6.0, 50), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
W=(u-v*1j)/(1-(c/z)**2)
size=10
x_start,x_end=-3,3
y_start,y_end=-3,3
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.quiver(x4,y4,u,v,units='xy',pivot='tip',width=0.005,scale=40)

# %%
cp = 1.0 - (u**2+v**2)/u_inf**2

# plot the pressure coefficient field
size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('z-plane', fontsize=16)
contf = pyplot.contourf(x4, y4, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])

# %%
W = (u - v*1j)/(1-(c/z)**2)
size=10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.quiver(xi_5.real,xi_5.imag,W.real,-W.imag,units='xy',pivot='tip',width=0.005,scale=40)

# %%
u_1 = W.real
v_1 = -W.imag
cp_xi = 1.0 - (u_1**2+v_1**2)/u_inf**2

size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('xi-plane', fontsize=16)
contf = pyplot.contourf(xi_5.real, xi_5.imag, cp_xi, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])

# %%
cp_xi[74][0]
# Out:
# -0.15585265148902283

# %%
W[49,0]
# Out:
# (1.4503736703270318-0.032970063991349198j)

# %% [markdown]
# # 6. Flow over a symmetric Joukowski airfoil with non-zero angle of attack, with circulation

# %%
gamma = -1*4*math.pi*1.15*numpy.sin(-20*math.pi/180)

# %%
def get_velocity_vortex(strength, xv, yv, X, Y):
 
    u = + strength/(2*math.pi)*(Y-yv)/((X-xv)**2+(Y-yv)**2)
    v = - strength/(2*math.pi)*(X-xv)/((X-xv)**2+(Y-yv)**2)
    return u, v

def get_stream_function_vortex(strength, xv, yv, X, Y):

    psi = strength/(4*math.pi)*numpy.log((X-xv)**2+(Y-yv)**2)
    
    return psi

# %%
u_vortex, v_vortex = get_velocity_vortex(gamma, 0, 0, x4, y4)
psi_vortex = get_stream_function_vortex(gamma, 0, 0, x4, y4)

u = u + u_vortex
v = v + v_vortex
psi = psi + psi_vortex

# %%
size = 5
x_start,x_end=-6,6
y_start,y_end=-6,6
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('z-plane',fontsize=16)
pyplot.contour(x4, y4, psi, levels=numpy.linspace(-6.0, 6.0, 51), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.xlabel('xi-plane',fontsize=16)
pyplot.contour(xi_5.real, xi_5.imag, psi, levels=numpy.linspace(-6.0, 6.0, 51), colors='#CD2305', linewidths=2, linestyles='solid')

# %%
W=(u-v*1j)/(1-(c/z)**2)
size=10
x_start,x_end=-3,3
y_start,y_end=-3,3
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.quiver(x4,y4,u,v,units='xy',pivot='tip',width=0.005,scale=40)

# %%
W = (u - v*1j)/(1-(c/z)**2)
size=10
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlim(x_start,x_end)
pyplot.ylim(y_start,y_end)
pyplot.quiver(xi_5.real,xi_5.imag,u,v,units='xy',pivot='tip',width=0.005,scale=40)

# %%
cp = 1.0 - (u**2+v**2)/u_inf**2

# plot the pressure coefficient field
size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('z-plane', fontsize=16)
contf = pyplot.contourf(x4, y4, cp, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])

# %%
u_1 = W.real
v_1 = -W.imag
cp_xi = 1.0 - (u_1**2+v_1**2)/u_inf**2

size = 5
pyplot.figure(figsize=(size, (y_end-y_start)/(x_end-x_start)*size))
pyplot.xlabel('xi-plane', fontsize=16)
contf = pyplot.contourf(xi_5.real, xi_5.imag, cp_xi, levels=numpy.linspace(-0.88, 0.88, 100), extend='both')
cbar = pyplot.colorbar(contf)
cbar.set_label('$C_p$', fontsize=16)
cbar.set_ticks([-0.88,-0.66,-0.44,-0.22,0.00, 0.22,0.44,0.66,0.88])

# %%
gamma
# Out:
# 4.9426446603975842

# %%
W[91][0]
# Out:
# (0.22570216651136149-0.071675524543836855j)

# %%
cp_xi[110][0]
# Out:
# 0.48828236118545698
